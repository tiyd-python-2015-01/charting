# %%
import random
import math
import statistics as stat
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
def coin_flip():
    """Let 1 signify heads and 0 signify tails."""
    return random.randint(0, 1)

# %%
def powers_of_two_with_n(n=100000):
    """Returns a list of the powers of two less than n, and n."""
    powers_of_two = []
    under_n = True
    current_exponent = 0
    while under_n:
        if 2**current_exponent > n:
            under_n = False
        else: 
            powers_of_two.append(2**current_exponent)
            current_exponent += 1
    powers_of_two.append(n)
    return powers_of_two


def coin_trial(num_trials=100000):
    """Runs a coin-flipping simulation for num_trials rounds, where num_trials defaults to 100000"""
    # precompute powers of two less than num_trials.
    powers_of_two = []
    under_n = True
    current_exponent = 0
    while under_n:
        if 2**current_exponent > num_trials:
            under_n = False
        else: 
            powers_of_two.append(2**current_exponent)
            current_exponent += 1
    trial_list = []
    heads_total = 0
    for trial_num in range(1, num_trials + 1):
        heads_total += coin_flip()
        if trial_num in powers_of_two:
            trial_list.append((trial_num, heads_total))
    trial_list.append((num_trials, heads_total))
    return trial_list

# %%
trial_1 = coin_trial()

def string_power_of_two(given_num):
    power = math.log2(given_num)
    exponential_string = "2**{}".format(round(power, 2))
    return exponential_string

def diff_heads_minus_tails(given_tuple):
    return given_tuple[1] - given_tuple[0] + given_tuple[1]


def ratio_heads_tails(given_tuple):
    if (given_tuple[0] - given_tuple[1]) is 0:
        return 0
    return given_tuple[1] / (given_tuple[0] - given_tuple[1])


print(trial_1)

diff_heads = [diff_heads_minus_tails(heads) for heads in trial_1]
print(diff_heads)

ratio_heads = [ratio_heads_tails(heads) for heads in trial_1]
print(ratio_heads)
# Out:
# [(1, 1), (2, 2), (4, 2), (8, 4), (16, 10), (32, 18), (64, 28), (128, 63), (256, 125), (512, 259), (1024, 505), (2048, 1012), (4096, 2077), (8192, 4104), (16384, 8185), (32768, 16453), (65536, 32944), (100000, 50092)]
# [1, 2, 0, 0, 4, 4, -8, -2, -6, 6, -14, -24, 58, 16, -14, 138, 352, 184]
# [0, 0, 1.0, 1.0, 1.6666666666666667, 1.2857142857142858, 0.7777777777777778, 0.9692307692307692, 0.9541984732824428, 1.023715415019763, 0.9730250481695568, 0.9768339768339769, 1.0287270926201089, 1.0039138943248533, 0.9982924746920356, 1.0084584737971192, 1.0108001963672066, 1.0036867836819747]

# %%
plt.plot(diff_heads)
#plt.xticks(range(len(trial_1)), [string_power_of_two(num[0]) for num in trial_1])
plt.show()

# %%
plt.plot(ratio_heads)
#plt.xticks(range(len(trial_1)), [string_power_of_two(num[0]) for num in trial_1])
plt.show()

# %%
plt.scatter([num[0] for num in trial_1], ratio_heads)
plt.xscale('log')
#plt.xticks([num[0] for num in trial_1], [string_power_of_two(num[0]) for num in trial_1])

# %%
plt.scatter([num[0] for num in trial_1], diff_heads)
plt.xscale('log')
#plt.xticks([num[0] for num in trial_1], [string_power_of_two(num[0]) for num in trial_1])

# %%
trial_list = []
for _ in range(20):
    trial_list.append(coin_trial())
ratio_list = []
for _ in range(20):
    pre_ratio_trial = coin_trial()
    ratio_trial = [(ratio_heads_tails(trial))
                   for trial in pre_ratio_trial]
    ratio_list.append(ratio_trial)
print(ratio_list)
# Out:
# [[0.0, 1.0, 1.0, 0.6, 0.6, 0.7777777777777778, 0.9393939393939394, 0.9104477611940298, 0.9692307692307692, 0.9104477611940298, 1.0039138943248533, 0.9922178988326849, 0.9922178988326849, 1.018231091401823, 1.0202219482120838, 0.999267846247712, 1.0094437971423316, 1.0042891788427235], [0, 0, 3.0, 7.0, 2.2, 1.9090909090909092, 1.9090909090909092, 1.1333333333333333, 0.841726618705036, 0.9467680608365019, 0.914018691588785, 0.9504761904761905, 0.9902818270165209, 0.9739759036144578, 0.9749276759884281, 0.9934298576469157, 0.9831749682261091, 0.986531317666223], [0.0, 1.0, 3.0, 1.6666666666666667, 2.2, 1.4615384615384615, 1.206896551724138, 1.2456140350877194, 1.2456140350877194, 1.1694915254237288, 1.1200828157349896, 1.037810945273632, 0.9922178988326849, 0.994157740993184, 0.9794611574241875, 0.9882288696074267, 0.9947040024349414, 0.9912385503783353], [0, 0, 0, 7.0, 1.2857142857142858, 0.8823529411764706, 0.8285714285714286, 0.8285714285714286, 0.9692307692307692, 0.9768339768339769, 0.9320754716981132, 0.9864209505334627, 1.0019550342130987, 0.9859393939393939, 0.9963445838917997, 0.9887115372944104, 0.989073691878111, 0.986294567484358], [0, 1.0, 0.3333333333333333, 0.14285714285714285, 0.3333333333333333, 0.6, 0.8823529411764706, 1.064516129032258, 0.9692307692307692, 0.9467680608365019, 0.914018691588785, 0.9749276759884281, 1.015748031496063, 0.9922178988326849, 1.0108001963672066, 1.0176097530940214, 1.0117260644012647, 1.0044498787307823], [0.0, 1.0, 0.3333333333333333, 0.3333333333333333, 0.6, 1.1333333333333333, 1.206896551724138, 1.0317460317460319, 1.015748031496063, 0.9692307692307692, 0.9654510556621881, 0.9864209505334627, 1.0048947626040137, 0.987867022567338, 0.994157740993184, 0.9895567698846387, 0.9993898346451888, 0.9937794082462716], [0, 1.0, 1.0, 0.6, 1.0, 1.0, 0.8285714285714286, 0.8285714285714286, 0.8823529411764706, 0.9176029962546817, 0.9430740037950665, 0.9844961240310077, 0.9720751083293211, 0.9835351089588378, 0.9978051457139373, 1.0, 0.9987190826191711, 1.0018016214593133], [0, 0, 3.0, 1.6666666666666667, 1.6666666666666667, 1.1333333333333333, 0.9393939393939394, 1.0317460317460319, 1.0317460317460319, 0.8618181818181818, 1.015748031496063, 1.0217176702862785, 0.9951290793960058, 0.9835351089588378, 0.9902818270165209, 0.9957366465680005, 0.9925207503572406, 0.9984012789768185], [0, 0, 3.0, 3.0, 2.2, 1.2857142857142858, 1.56, 1.2456140350877194, 1.2260869565217392, 1.1974248927038627, 1.0686868686868687, 1.0418743768693919, 1.0728744939271255, 1.0449326010983524, 1.0428927680798006, 1.0262181548355183, 1.0064907231645337, 1.0022826021664697], [0.0, 0.0, 0.3333333333333333, 0.6, 0.3333333333333333, 0.7777777777777778, 1.0, 0.855072463768116, 0.8962962962962963, 0.9393939393939394, 0.9033457249070632, 0.9523355576739753, 1.0009770395701025, 0.9975615703486954, 0.987384764677341, 0.9991458727350375, 0.9947647166250685, 1.0], [0, 0, 1.0, 0.6, 0.7777777777777778, 0.8823529411764706, 1.0, 0.9393939393939394, 1.08130081300813, 0.9922178988326849, 1.0562248995983936, 1.0357852882703777, 0.9739759036144578, 0.9946432919405892, 1.0167405219103889, 1.0048947626040137, 1.008027698624261, 1.0007202592933455], [0, 0, 3.0, 1.0, 1.2857142857142858, 0.8823529411764706, 0.7297297297297297, 1.0, 1.064516129032258, 1.0, 1.0357852882703777, 1.0418743768693919, 1.0058765915768855, 1.0137659783677482, 1.0115408225905465, 1.005262835811762, 1.0007326901941629, 0.999120387029707], [0.0, 0.0, 0.3333333333333333, 0.6, 1.2857142857142858, 1.1333333333333333, 1.4615384615384615, 1.2857142857142858, 1.064516129032258, 0.9922178988326849, 0.928436911487759, 0.9825750242013552, 1.0108001963672066, 0.971126082771896, 0.9842557829720238, 1.005262835811762, 1.0015881742104942, 1.0009604610212903], [0, 0, 3.0, 3.0, 1.2857142857142858, 1.6666666666666667, 1.2857142857142858, 1.4150943396226414, 1.348623853211009, 1.1422594142259415, 1.0117878192534382, 0.9922178988326849, 0.9768339768339769, 1.0014659174199854, 0.9987800414785897,  ...

# %%
plt.scatter(powers_of_two_with_n(), ratio_list[0])

# %%
means_coin_ratio = [stat.mean([ratio_list[trial_num][count_num] 
                                 for trial_num in range(len(ratio_list))])
                                 for count_num in range(len(powers_of_two_with_n()))]

print(means_coin_ratio)
# Out:
# [0.0, 0.45, 1.5, 1.7504761904761907, 1.2108225108225108, 1.1099837417484477, 1.0993605420102834, 1.063117273228754, 1.022064738803134, 0.9822623975720155, 0.9871271322487614, 0.9896270473022497, 0.9951648978353532, 0.9934865548773562, 0.9994150889064566, 1.0000816287044945, 0.999388218254459, 0.9984081565909315]

# %% [markdown]
# The above is literally the most infuriating, mind-boggling list comprehension I have ever written.
